# %%
pip install opencv-python
# Out:
# ...
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/c7/ec/9dabb6a9abfdebb3c45b0cc52dec901caafef2b2c7e7d6a839ed86d81e91/opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB 1.3 MB/s eta 0:00:31
#    ---------------------------------------- 0.1/38.6 MB 812.7 kB/s eta 0:00:48
#    ---------------------------------------- 0.1/38.6 MB 871.5 kB/s eta 0:00:45
#    ---------------------------------------- 0.1/38.6 MB 798.9 kB/s eta 0:00:49
#    ---------------------------------------- 0.2/38.6 MB 871.5 kB/s eta 0:00:45
#    ---------------------------------------- 0.2/38.6 MB 915.1 kB/s eta 0:00:42
#    ---------------------------------------- 0.3/38.6 MB 999.9 kB/s eta 0:00:39
#    ---------------------------------------- 0.4/38.6 MB 1.1 MB/s eta 0:00:37
# ...

# %%
import cv2

# %%
img=cv2.imread('sample2.jpg')#image read
cv2.imshow('sample2 image', img)
cv2.waitKey(1000)#millisecond
cv2.destroyAllWindows()#all windows closed
cv2.destroyWindow()#only one window
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       3 cv2.waitKey(1000)#millisecond
#       4 cv2.destroyAllWindows()#all windows closed
# ----> 5 cv2.destroyWindow()
#
# TypeError: destroyWindow() missing required argument 'winname' (pos 1)
