# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:\\Users\\kunal\\OneDrive\\CODE FOR LIFE\\Python projects\\Python Libraries\\Untitled Folder\\tips.csv')#csv_file-> comma seperated file
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.iloc[0:4]
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260

# %%
df=df.set_index('Payment ID')#permantly changed

# %%
df.iloc[0:4]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %%
df.loc['Sun2959']
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# Name: Sun2959, dtype: object

# %%
df.loc[['Sun2959', 'Sun5260']]  
#iloc integer based
#loc lock string label index based
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun5260                11.84    Nathaniel Harris  4676137647685994

# %%
df.drop('Sun2959',axis=0)
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# ...

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221

# %%
df=df.drop('Sun2959',axis=0)

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# Sun4458                 7.00    Travis Walters  6011812112971322
# Sun5260                11.84  Nathaniel Harris  4676137647685994
# Sun2251                 6.15      Tonya Carter  4832732618637221
# Sun9679                 6.32        Erik Smith   213140353657882

# %%
one_row=df.iloc[0]

# %%
one_row
# Out:
# total_bill                     10.34
# tip                             1.66
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                3.45
# Payer Name            Douglas Tucker
# CC Number           4478071379779230
# Name: Sun4608, dtype: object

# %%
df=df.append(one_row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35580\711828457.py in ?()
# ----> 1 df=df.append(one_row)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
#condintional filtering 
# filter by single condition
# filter by multiple coondintions 
# check against multiple possibel values

# %%
bool_series=df['total_bill']>40

# %%
df[bool_series]
# Out:
#             total_bill    tip     sex smoker   day    time  size  \
# Payment ID
# Sat8139          48.27   6.73    Male     No   Sat  Dinner     4
# Fri9628          40.17   4.73    Male    Yes   Fri  Dinner     4
# Sat6240          44.30   2.50  Female    Yes   Sat  Dinner     3
# Thur3621         41.19   5.00    Male     No  Thur   Lunch     5
# Sun7518          48.17   5.00    Male     No   Sun  Dinner     6
# Sat1954          50.81  10.00    Male    Yes   Sat  Dinner     3
# Sun2337          45.35   3.50    Male    Yes   Sun  Dinner     3
# Sun5140          40.55   3.00    Male    Yes   Sun  Dinner     2
# Thur9313         43.11   5.00  Female    Yes  Thur   Lunch     4
# Sat4590          48.33   9.00    Male     No   Sat  Dinner     4
#
#             price_per_person       Payer Name         CC Number
# Payment ID
# Sat8139                12.07      Brian Ortiz  6596453823950595
# Fri9628                10.04    Aaron Bentley   180026611638690
# ...

# %%
df[df['sex']=='Male']
# Out:
#             total_bill   tip   sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66  Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50  Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31  Male     No  Sun  Dinner     2
# Sun9679          25.29  4.71  Male     No  Sun  Dinner     4
# Sun5985           8.77  2.00  Male     No  Sun  Dinner     2
# ...                ...   ...   ...    ...  ...     ...   ...
# Sat5032          12.60  1.00  Male    Yes  Sat  Dinner     2
# Sat2929          32.83  1.17  Male    Yes  Sat  Dinner     2
# Sat2657          29.03  5.92  Male     No  Sat  Dinner     3
# Sat3880          22.67  2.00  Male    Yes  Sat  Dinner     2
# Sat17            17.82  1.75  Male     No  Sat  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# ...

# %%
df[df['size']>5]
# Out:
#             total_bill  tip     sex smoker   day    time  size  \
# Payment ID
# Thur3948         29.80  4.2  Female     No  Thur   Lunch     6
# Thur1025         34.30  6.7    Male     No  Thur   Lunch     6
# Thur6179         27.05  5.0  Female     No  Thur   Lunch     6
# Sun7518          48.17  5.0    Male     No   Sun  Dinner     6
#
#             price_per_person      Payer Name         CC Number
# Payment ID
# Thur3948                4.97  Angela Sanchez      503857080488
# Thur1025                5.72  Steven Carlson  3526515703718508
# Thur6179                4.51    Regina Jones     4311048695487
# Sun7518                 8.03   Ryan Gonzales  3523151482063321

# %%
df['total_bill']>30
df['sex']=='Male'
# Out:
# Payment ID
# Sun4608     True
# Sun4458     True
# Sun5260     True
# Sun2251    False
# Sun9679     True
#            ...
# Sat2657     True
# Sat1766    False
# Sat3880     True
# Sat17       True
# Thur672    False
# Name: sex, Length: 243, dtype: bool

# %%
df[(df['total_bill']>30)and (df['sex']=='Female')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35580\2587336566.py in ?()
# ----> 1 df[(df['total_bill']>30)and (df['sex']=='Female')]
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1469         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[(df['total_bill']>40)& (df['sex']=='Female')]
# Out:
#             total_bill  tip     sex smoker   day    time  size  \
# Payment ID
# Sat6240          44.30  2.5  Female    Yes   Sat  Dinner     3
# Thur9313         43.11  5.0  Female    Yes  Thur   Lunch     4
#
#             price_per_person     Payer Name         CC Number
# Payment ID
# Sat6240                14.77  Heather Cohen   379771118886604
# Thur9313               10.78    Brooke Soto  5544902205760175

# %%
df[(df['day']=='Sun')|(df['day']=='Sat')|(df['day']=='Mon')]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
# ...                ...   ...     ...    ...  ...     ...   ...
# Sat9777          35.83  4.67  Female     No  Sat  Dinner     3
# Sat2657          29.03  5.92    Male     No  Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes  Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes  Sat  Dinner     2
# Sat17            17.82  1.75    Male     No  Sat  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# ...

# %%
options=['Sun','Mon']
df[df['day'].isin(options)]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No  Sun  Dinner     4
# ...                ...   ...     ...    ...  ...     ...   ...
# Sun4254          20.90  3.50  Female    Yes  Sun  Dinner     3
# Sun9987          30.46  2.00    Male    Yes  Sun  Dinner     5
# Sun430           18.15  3.50  Female    Yes  Sun  Dinner     3
# Sun1821          23.10  4.00    Male    Yes  Sun  Dinner     3
# Sun5104          15.69  1.50    Male    Yes  Sun  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# Payment ID
# Sun4608                 3.45    Douglas Tucker  4478071379779230
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 243 entries, Sun4608 to Thur672
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        243 non-null    float64
#  1   tip               243 non-null    float64
#  2   sex               243 non-null    object
#  3   smoker            243 non-null    object
#  4   day               243 non-null    object
#  5   time              243 non-null    object
#  6   size              243 non-null    int64
#  7   price_per_person  243 non-null    float64
#  8   Payer Name        243 non-null    object
#  9   CC Number         243 non-null    int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 29.0+ KB

# %%
str(4478071379779230)[0]
# Out:
# '4'

# %%
str(4478071379779230)[-4:]
# Out:
# '9230'

# %%
def LastFour(num):
    return str(num)[-4:]

# %%
LastFour(4478071379779230)
# Out:
# '9230'

# %%
df['LastFour']=df['CC Number'].apply(LastFour)

# %%
df['total_bill']
# Out:
# Payment ID
# Sun4608    10.34
# Sun4458    21.01
# Sun5260    23.68
# Sun2251    24.59
# Sun9679    25.29
#            ...
# Sat2657    29.03
# Sat1766    27.18
# Sat3880    22.67
# Sat17      17.82
# Thur672    18.78
# Name: total_bill, Length: 243, dtype: float64

# %%
df['total_bill'].mean()
# Out:
# 19.797448559670784

# %%
def yelp(price):
    if price<10:
        return '$'
    elif price>=10 and price<30:
        return '$$'
    else:
        return '$$$'
# Out:
#   Cell In[47], line 3
#     return $
#            ^
# SyntaxError: invalid syntax
